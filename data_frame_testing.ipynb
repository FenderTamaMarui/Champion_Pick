# %% [markdown]
# # The purpose of this file is to compare Covid Case Trends with Streaming Platform Use
#
# ### As well as getting used to matplot

# %%
import pandas as pd
import os
import requests
import matplotlib.pyplot as plt

pwd = os.getcwd()

# %% [markdown]
# ## Importing the Covid Data

# %%
dataset = pd.read_csv(pwd + "/big_query_covid_data.csv")
dataset
# Out:
#              date                   countries_and_territories  year  \
# 0      2020-03-20                                        Chad  2020
# 1      2020-03-21                                        Chad  2020
# 2      2020-03-22                                        Chad  2020
# 3      2020-03-23                                        Chad  2020
# 4      2020-03-24                                        Chad  2020
# ...           ...                                         ...   ...
# 61828  2020-02-24  Cases_on_an_international_conveyance_Japan  2020
# 61829  2020-02-26  Cases_on_an_international_conveyance_Japan  2020
# 61830  2020-03-10  Cases_on_an_international_conveyance_Japan  2020
# 61831  2020-02-20  Cases_on_an_international_conveyance_Japan  2020
# 61832  2020-02-29  Cases_on_an_international_conveyance_Japan  2020
#
#        daily_confirmed_cases  daily_deaths
# 0                          1             0
# 1                          0             0
# ...

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#              date                   countries_and_territories  year  \
# 0      2020-03-20                                        Chad  2020
# 1      2020-03-21                                        Chad  2020
# 2      2020-03-22                                        Chad  2020
# 3      2020-03-23                                        Chad  2020
# 4      2020-03-24                                        Chad  2020
# ...           ...                                         ...   ...
# 61828  2020-02-24  Cases_on_an_international_conveyance_Japan  2020
# 61829  2020-02-26  Cases_on_an_international_conveyance_Japan  2020
# 61830  2020-03-10  Cases_on_an_international_conveyance_Japan  2020
# 61831  2020-02-20  Cases_on_an_international_conveyance_Japan  2020
# 61832  2020-02-29  Cases_on_an_international_conveyance_Japan  2020
#
#        daily_confirmed_cases  daily_deaths
# 0                          1             0
# 1                          0             0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20144/1449302889.py in <module>
# ----> 1 dataset_modified.groupby(column = 'date')
#
# TypeError: groupby() got an unexpected keyword argument 'column'
